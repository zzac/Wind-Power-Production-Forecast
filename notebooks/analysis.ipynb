# %% [markdown]
# # Analyse

# %% [markdown]
# ## Import des modules

# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/dataset_1.parquet')

print(df.head())
print(df.info())
# Out:
#                      site_name             delivery_time  production  \
# 0  Nobelwind Offshore Windpark 2022-12-31 23:00:00+00:00    162.7175
# 1  Nobelwind Offshore Windpark 2023-01-01 00:00:00+00:00    162.6850
# 2  Nobelwind Offshore Windpark 2023-01-01 01:00:00+00:00    162.6800
# 3  Nobelwind Offshore Windpark 2023-01-01 02:00:00+00:00    162.7300
# 4  Nobelwind Offshore Windpark 2023-01-01 03:00:00+00:00    162.7125
#
#    installed_capacity
# 0               165.0
# 1               165.0
# 2               165.0
# 3               165.0
# 4               165.0
# <class 'pandas.DataFrame'>
# RangeIndex: 274800 entries, 0 to 274799
# Data columns (total 4 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   site_name           274800 non-null  str
#  1   delivery_time       274800 non-null  datetime64[ns, UTC]
#  2   production          274704 non-null  float64
#  3   installed_capacity  274800 non-null  float64
# ...
