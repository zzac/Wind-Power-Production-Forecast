# %% [markdown]
# # Merge Datasets into one `merged_dataset.parquet` and `merged_dataset.csv`

# %%
from utils.datasets import load_full_dataset

full_dataset = load_full_dataset()

full_dataset.to_csv("../data/merged_dataset.csv", index=False)
print("Saved to CSV")

full_dataset.to_parquet("../data/merged_dataset.parquet", index=False)
print("Saved to Parquet")
# Out:
# Saved to CSV
# Saved to Parquet

# %%
full_dataset.head(5)
# Out:
#          site_name             delivery_time  production  installed_capacity  \
# 0  Belwind Phase 1 2023-01-01 00:00:00+00:00    147.7025               171.0
# 1  Belwind Phase 1 2023-01-01 01:00:00+00:00    146.1775               171.0
# 2  Belwind Phase 1 2023-01-01 02:00:00+00:00    146.1800               171.0
# 3  Belwind Phase 1 2023-01-01 03:00:00+00:00    146.5050               171.0
# 4  Belwind Phase 1 2023-01-01 04:00:00+00:00    146.6950               171.0
#
#    wind_speed_10m  wind_speed_100m  wind_direction_10m  wind_direction_100m  \
# 0       14.603082        19.897738           218.04709            219.28940
# 1       16.182089        21.681328           215.94937            217.50421
# 2       17.969420        23.809662           226.80397            228.74626
# 3       14.792228        19.860010           227.46579            229.49266
# 4       15.001333        19.915070           227.16109            228.86830
#
# ...
