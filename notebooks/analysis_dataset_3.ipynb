# %% [markdown]
# # Analyse dataset 3

# %% [markdown]
# Contient les données météo.

# %% [markdown]
# ## Import des modules

# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/dataset_3.parquet')

print(df.head())
print(df.info())
# Out:
#          site_name              delivery_time  wind_speed_10m  \
# 0  Belwind Phase 1  2023-01-01 00:00:00+00:00       14.603082
# 1  Belwind Phase 1  2023-01-01 01:00:00+00:00       16.182089
# 2  Belwind Phase 1  2023-01-01 02:00:00+00:00       17.969420
# 3  Belwind Phase 1  2023-01-01 03:00:00+00:00       14.792228
# 4  Belwind Phase 1  2023-01-01 04:00:00+00:00       15.001333
#
#    wind_speed_100m  wind_direction_10m  wind_direction_100m  wind_gusts_10m  \
# 0        19.897738           218.04709            219.28940            20.7
# 1        21.681328           215.94937            217.50421            20.8
# 2        23.809662           226.80397            228.74626            24.1
# 3        19.860010           227.46579            229.49266            23.9
# 4        19.915070           227.16109            228.86830            19.7
#
#    temperature_2m  dewpoint_2m  apparent_temperature  ...  snowfall  \
# ...
